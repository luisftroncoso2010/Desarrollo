# %%
lista = [1, 2, 3]
lista[0] = 1000
print(lista)
# Out:
# [1000, 2, 3]

# %%
tuplas = (1, 2, 3, 4)
tuplas[0] = 1000  # Marcará error
print(tuplas)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 tuplas = (1, 2, 3, 4)
# ----> 2 tuplas[0] = 1000
#       3 print(tuplas)
#
# TypeError: 'tuple' object does not support item assignment
