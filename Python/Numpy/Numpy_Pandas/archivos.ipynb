# %%
import pandas as pd
import json

# %%
# Leer archivo csv. Le damos el nombre del archivo, le asignamos el titulo, los valores 
csv = pd.read_csv('./bestsellers with categories.csv', sep=',', header=0, names=['Name', 'Author', 'User Rating', 'Reviews', 'Price', 'Year', 'Genre'] )
csv
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
# Leemos un json
jsonnUno = pd.read_json('./HPCharactersDataRaw.json')
jsonnUno
# Out:
#                       Name                                               Link  \
# 0              Mrs. Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 1            Hannah Abbott  https://www.hp-lexicon.org/character/abbott-fa...
# 2            Abel Treetops  https://www.hp-lexicon.org/character/abel-tree...
# 3         Euan Abercrombie  https://www.hp-lexicon.org/character/abercromb...
# 4     Aberforth Dumbledore  https://www.hp-lexicon.org/character/dumbledor...
# ...                    ...                                                ...
# 1935        Georgi Zdravko  https://www.hp-lexicon.org/character/georgi-zd...
# 1936                Zograf       https://www.hp-lexicon.org/character/zograf/
# 1937                 Zonko        https://www.hp-lexicon.org/character/zonko/
# 1938     Valentina Vázquez  https://www.hp-lexicon.org/character/valentina...
# 1939         Zygmunt Budge  https://www.hp-lexicon.org/character/zygmunt-b...
#
# ...

# %%
# Leemos un json
jsonn = pd.read_json('./HPCharactersDataRaw.json', typ='Series')
jsonn
# Out:
# 0       {'Name': 'Mrs. Abbott', 'Link': 'https://www.h...
# 1       {'Name': 'Hannah Abbott', 'Link': 'https://www...
# 2       {'Name': 'Abel Treetops', 'Link': 'https://www...
# 3       {'Name': 'Euan Abercrombie', 'Link': 'https://...
# 4       {'Name': 'Aberforth Dumbledore', 'Link': 'http...
#                               ...
# 1935    {'Name': 'Georgi Zdravko', 'Link': 'https://ww...
# 1936    {'Name': 'Zograf', 'Link': 'https://www.hp-lex...
# 1937    {'Name': 'Zonko', 'Link': 'https://www.hp-lexi...
# 1938    {'Name': 'Valentina Vázquez', 'Link': 'https:/...
# 1939    {'Name': 'Zygmunt Budge', 'Link': 'https://www...
# Length: 1940, dtype: object

# %%
# Pasamos ambos archivps a dataframe
json_str = jsonn.to_json()  # Esto lo convierte a una cadena de JSON
json_str
# Out:
# '{"0":{"Name":"Mrs. Abbott","Link":"https:\\/\\/www.hp-lexicon.org\\/character\\/abbott-family\\/mrs-abbott\\/","Descr":"Mrs. Abbott was the mother of Hannah Abbott, a Hufflepuff in Harry\\u2019s year. Mrs. Abbott was found dead in the fall of 1996, having been murdered by Death Eaters (HBP11). ","Gender":"Female","Species\\/Race":"Witch","Blood":"Muggle-born","School":"Unknown","Profession":"Unknown"},"1":{"Name":"Hannah Abbott","Link":"https:\\/\\/www.hp-lexicon.org\\/character\\/abbott-family\\/hannah-abbott\\/","Descr":"Hannah Abbott is a Hufflepuff student in Harry\\u2019s year at Hogwarts. A pink-faced blonde girl who wears her hair in pigtails (PS7), Hannah is a close friend of\\u00a0Ernie Macmillan\\u00a0(CS11,\\u00a0CS15), who shares her hobby of collecting\\u00a0chocolate frog cards\\u00a0(GF19). Both Hannah and\\u2026 ","Gender":"Female","Species\\/Race":"Witch","Blood":"Half-blood","School":"Hogwarts - Hufflepuff","Profession":"Landlady of the Leaky Cauldron"},"2":{"Name"
# ...

# %%
# Ahora pasamos la cadena de json a 
data = json.loads(json_str)
data
# Out:
# {'0': {'Name': 'Mrs. Abbott',
#   'Link': 'https://www.hp-lexicon.org/character/abbott-family/mrs-abbott/',
#   'Descr': 'Mrs. Abbott was the mother of Hannah Abbott, a Hufflepuff in Harry’s year. Mrs. Abbott was found dead in the fall of 1996, having been murdered by Death Eaters (HBP11). ',
#   'Gender': 'Female',
#   'Species/Race': 'Witch',
#   'Blood': 'Muggle-born',
#   'School': 'Unknown',
#   'Profession': 'Unknown'},
#  '1': {'Name': 'Hannah Abbott',
#   'Link': 'https://www.hp-lexicon.org/character/abbott-family/hannah-abbott/',
#   'Descr': 'Hannah Abbott is a Hufflepuff student in Harry’s year at Hogwarts. A pink-faced blonde girl who wears her hair in pigtails (PS7), Hannah is a close friend of\xa0Ernie Macmillan\xa0(CS11,\xa0CS15), who shares her hobby of collecting\xa0chocolate frog cards\xa0(GF19). Both Hannah and… ',
#   'Gender': 'Female',
#   'Species/Race': 'Witch',
#   'Blood': 'Half-blood',
#   'School': 'Hogwarts - Hufflepuff',
# ...
